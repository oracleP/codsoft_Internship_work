# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_card_data=pd.read_csv('/content/creditcard.csv')

# %%
# first five rows of the datasets
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 25833  33785 -0.187402  0.445507  2.199225  3.030535 -0.361376  1.095100
# 25834  33785  1.237064  0.312096  0.191934  0.496764 -0.129777 -0.551625
# 25835  33785  1.245292 -0.594493  0.275982 -0.578346 -0.920599 -0.865570
# 25836  33787 -0.697373  0.401180  0.803750 -1.015524 -0.226100  0.283660
# 25837  33787  1.303469  0.498450       NaN       NaN       NaN       NaN
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 25833 -0.119594  0.245950 -0.371890  ...  0.154001  0.813468  0.377732
# 25834 -0.007160 -0.048880 -0.240393  ... -0.255114 -0.759423  0.072774
# 25835 -0.321689 -0.217249 -1.007295  ...  0.303333  0.736260 -0.102900
# 25836  0.094868  0.077613 -1.327124  ...  0.118688  0.467655 -0.162958
# 25837       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25838 entries, 0 to 25837
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    25838 non-null  int64
#  1   V1      25838 non-null  float64
#  2   V2      25838 non-null  float64
#  3   V3      25837 non-null  float64
#  4   V4      25837 non-null  float64
#  5   V5      25837 non-null  float64
#  6   V6      25837 non-null  float64
#  7   V7      25837 non-null  float64
#  8   V8      25837 non-null  float64
#  9   V9      25837 non-null  float64
#  10  V10     25837 non-null  float64
#  11  V11     25837 non-null  float64
#  12  V12     25837 non-null  float64
#  13  V13     25837 non-null  float64
#  14  V14     25837 non-null  float64
#  15  V15     25837 non-null  float64
#  16  V16     25837 non-null  float64
#  17  V17     25837 non-null  float64
#  18  V18     25837 non-null  float64
#  19  V19     25837 non-null  float64
# ...

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        1
# V4        1
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
credit_card_data[credit_card_data.isnull().any(axis=1)]
# Out:
#         Time        V1       V2  V3  V4  V5  V6  V7  V8  V9  ...  V21  V22  \
# 25837  33787  1.303469  0.49845 NaN NaN NaN NaN NaN NaN NaN  ...  NaN  NaN
#
#        V23  V24  V25  V26  V27  V28  Amount  Class
# 25837  NaN  NaN  NaN  NaN  NaN  NaN     NaN    NaN
#
# [1 rows x 31 columns]

# %%
credit_card_data=credit_card_data.dropna()

# %% [markdown]
# # here distribution of legit transaction & fraudulent **trransaction**

# %%
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    25749
# 1.0       88
# Name: count, dtype: int64

# %% [markdown]
# This Dataset is highly unblanced

# %% [markdown]
# ## 0->Normal Transaction
# ## 1->fraudulent Transaction

# %%
#separating the data for analysis
legit =credit_card_data[credit_card_data.Class==0]
fraud=credit_card_data[credit_card_data.Class==1]

# %%
legit=legit.dropna()
fraud=fraud.dropna()

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (25749, 31)
# (88, 31)

# %%
legit
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 25832  33784  1.261980 -0.325252 -0.143104 -1.105445 -0.156888  0.006692
# 25833  33785 -0.187402  0.445507  2.199225  3.030535 -0.361376  1.095100
# 25834  33785  1.237064  0.312096  0.191934  0.496764 -0.129777 -0.551625
# 25835  33785  1.245292 -0.594493  0.275982 -0.578346 -0.920599 -0.865570
# 25836  33787 -0.697373  0.401180  0.803750 -1.015524 -0.226100  0.283660
#
#              V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
#stastical measure of the data\
legit.Amount.describe()
# Out:
# count    25749.000000
# mean        75.726227
# std        219.488324
# min          0.000000
# 25%          6.200000
# 50%         18.960000
# 75%         67.500000
# max       7879.420000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      88.000000
# mean      100.010000
# std       265.845031
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
# compare the value for both.transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    19380.491087 -0.197045  0.145743   0.767372  0.208854 -0.174420
# 1.0    17935.875000 -8.613716  6.376169 -12.221731  6.231847 -6.027247
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.088572 -0.100712  0.011278  0.453641  ...  0.039986 -0.039570
# 1.0   -2.487080 -8.308784  4.351326 -2.987199  ...  0.714069  0.539387
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.131409 -0.038716  0.012076  0.128670  0.022883  0.010424  0.003824
# 1.0   -0.381823 -0.350615 -0.252970  0.346695  0.179760  0.856336  0.100578
#
#            Amount
# Class
# 0.0     75.726227
# 1.0    100.010000
#
# [2 rows x 30 columns]

# %% [markdown]
# ## UNDERSAMPLING

# %% [markdown]
# BUILD A SAMPLE DATASET CONTAIN SIMILAR DISTRIBUTION OF NORMAL TRANSACTION AND FRAUDULENT TRANSACTION

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# ##concatenation of two datasets

# %%
new_dataset=pd.concat([legit_sample,fraud],axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 15726  27158  1.160957  1.265621 -1.576473  1.472988  1.162173 -1.013532
# 18667  29674  1.192064 -0.110887  0.602662  0.400204 -0.483483 -0.175242
# 10767  18298  1.206694 -0.426007  1.130400 -0.414559 -1.511115 -1.016495
# 22464  32259  1.162168 -0.250281  1.128448  0.235416 -1.073551 -0.397156
# 13446  23788 -1.078153 -0.657243  2.697321 -1.063446 -1.452814  1.070204
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 15726  0.658133 -0.152624 -0.847326  ... -0.120365 -0.204997 -0.203189
# 18667 -0.322232 -0.047787  0.398757  ... -0.069611 -0.248543 -0.075232
# 10767 -0.803045 -0.005360  3.434208  ... -0.162267 -0.106986  0.035797
# 22464 -0.551141  0.029393  0.817284  ...  0.104111  0.609919  0.013266
# 13446  0.064407  0.319905  0.939743  ...  0.279681  0.962584  0.136185
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 18773  29753  0.269614  3.549755 -5.810353  5.809370  1.538808 -2.269219
# 18809  29785  0.923764  0.344048 -2.880004  1.721680 -3.019565 -0.639736
# 20198  30852 -2.830984  0.885657  1.199930  2.861292  0.321669  0.289966
# 23308  32686  0.287953  1.728735 -1.652173  3.813544 -1.090927 -0.984745
# 23422  32745 -2.179135  0.020218 -2.182733  2.572046 -3.663733  0.081568
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 18773 -0.824203  0.351070 -3.759059  ...  0.371121 -0.322290 -0.549856
# 18809 -3.801325  1.299096  0.864065  ...  0.899931  1.481271  0.725266
# 20198  1.767760 -2.451050  0.069736  ...  0.546589  0.334971  0.172106
# 23308 -2.202318  0.555088 -2.033892  ...  0.262202 -0.633528  0.092891
# 23422  0.268049  0.660437 -2.374027  ...  1.026421  0.299614  1.656800
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0     88
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    19742.296748 -0.247492  0.172933   0.826218  0.245261 -0.211572
# 1.0    17935.875000 -8.613716  6.376169 -12.221731  6.231847 -6.027247
#
#             V6        V7        V8        V9  ...       V20       V21  \
# Class                                         ...
# 0.0    0.07321 -0.033821 -0.006923  0.487162  ...  0.048921 -0.038244
# 1.0   -2.48708 -8.308784  4.351326 -2.987199  ...  0.714069  0.539387
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.119388 -0.040232  0.037888  0.095537  0.038607 -0.015734 -0.008322
# 1.0   -0.381823 -0.350615 -0.252970  0.346695  0.179760  0.856336  0.100578
#
#            Amount
# Class
# 0.0     82.025122
# 1.0    100.010000
#
# [2 rows x 30 columns]

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(Y)
# Out:
# 15726    0.0
# 18667    0.0
# 10767    0.0
# 22464    0.0
# 13446    0.0
#         ...
# 18773    1.0
# 18809    1.0
# 20198    1.0
# 23308    1.0
# 23422    1.0
# Name: Class, Length: 580, dtype: float64

# %% [markdown]
# SPLIT THE DATA INTO TRAINING AND TESTING DATA

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (580, 30) (464, 30) (116, 30)

# %% [markdown]
# MODEL TRAINING

# %% [markdown]
# lOGISTIC REGRESSION

# %%
model = LogisticRegression()

# %%
# training the Logistic Regression Model with Training Data
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline

model = make_pipeline(StandardScaler(), LogisticRegression(max_iter=1000))
model.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression(max_iter=1000))])

# %%
model = LogisticRegression(solver='liblinear', max_iter=1000)
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=1000, solver='liblinear')

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9827586206896551
